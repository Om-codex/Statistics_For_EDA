# %% [markdown]
# # Standardization

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
#Generate 1000 normal random integers with specified mean and std.
draw = norm.ppf(np.random.random(100000),loc = 1000, scale=200).astype(int)
sns.distplot(draw)
# Out:
# <Axes: ylabel='Density'>

# %%
z = []
for i in draw:
    z.append((i-1000)/200)

# %%
a = np.array(z)

# %%
print(a.mean())
print(np.round(a.mean()))
# Out:
# -0.0035848
# -0.0

# %%
print(a.std())
print(np.round(a.std()))
# Out:
# 0.9993442843729883
# 1.0

# %%
sns.distplot(a)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Calculating Z - Score

# %% [markdown]
# ## Problem 1: Imagine a group of 300 students took a test. Rohit scored 700 out of 1000. The average score was 500 and the standard deviation was 120. Assuming that the test scores followed normal distribution find out how well Rohit performed in comparison to his peers.

# %%
# step 1 - Calculate the z score
# formula => z = (x - mean)/std. deviation
# therfore,
z = (700 - 500)/120
print(z)
# Out:
# 1.6666666666666667

# %%
# step 2: Lookup the z table on the z table website
a = 0.95154

# %%
# step 3: Multiply it by 100
a*100
# Out:
# 95.15400000000001

# %% [markdown]
# ### So, Rohit performed better than 95% of his peers
